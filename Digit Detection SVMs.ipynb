# %%
import pandas as pd   
train_data=pd.read_csv(r'C:\Users\saurabh\Documents\Desktop\Neural Network and Deep Learning\digits detection\mnist_train.csv')
test_data=pd.read_csv(r'C:\Users\saurabh\Documents\Desktop\Neural Network and Deep Learning\digits detection\mnist_test.csv')
train_data.rename(columns={'5':'label'}, inplace=True)
test_data.rename(columns={'7':'label'}, inplace=True)
train_labels = train_data['label']
train_data=train_data.drop('label',axis=1)
test_labels = test_data['label']
test_data=test_data.drop('label',axis=1)
from sklearn.svm import SVC
clf=SVC(degree=1.0,C=1.0).fit(train_data,train_labels)

# %%
clf.score(test_datatest_labels)
# Out:
# 0.6025

# %%
import cv2
import matplotlib.pyplot as plt   
import numpy as np  
img=cv2.imread('2.jpg')
img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
img=cv2.resize(img,(28,28))
for i in range(28):
    for j in range(28):
        img[i][j]=abs(img[i][j]-255)

# %%
plt.imshow(img,cmap='Greys')

# %%
img=test_data.iloc[0]
img=np.array(img)
img=img.reshape(28,28)
plt.imshow(img,cmap='Greys')
